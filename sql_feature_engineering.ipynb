# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:WECHALE$0398_wess@localhost:3306/kingametrics
# Out:
# Connecting to 'mysql+pymysql://root:***@localhost:3306/kingametrics'

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN debt_to_income_ratio DECIMAL(10, 4);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET debt_to_income_ratio =
#     (
#         GREATEST(0, LEAST(Outstanding_Debt / (Annual_Income+1), 1))
#     )
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT Annual_Income, debt_to_income_ratio from risk_analysis_dataset LIMIT 5;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 5 rows affected.
# +---------------+----------------------+
# | Annual_Income | debt_to_income_ratio |
# +---------------+----------------------+
# |    34847.84   |        0.0174        |
# |    34847.84   |        0.0174        |
# |    30689.89   |        0.0206        |
# |   4148862.0   |        0.0002        |
# |    31370.8    |        0.0134        |
# +---------------+----------------------+

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN normalized_emi DECIMAL(10, 6);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET normalized_emi = (
#     GREATEST(0, LEAST(Total_EMI_per_month / (Monthly_Inhand_Salary+1), 1))
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT Annual_Income, normalized_emi from risk_analysis_dataset LIMIT 5;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 5 rows affected.
# +---------------+----------------+
# | Annual_Income | normalized_emi |
# +---------------+----------------+
# |    34847.84   |    0.006192    |
# |    34847.84   |    0.006192    |
# |    30689.89   |    0.006281    |
# |   4148862.0   |    0.006281    |
# |    31370.8    |    0.016494    |
# +---------------+----------------+

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN normalized_delinquency DECIMAL(10,6);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET normalized_delinquency = (
#     GREATEST(0, LEAST(Num_of_Delayed_Payment / (Num_of_Loan+1), 1))
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT Annual_Income, normalized_delinquency from risk_analysis_dataset LIMIT 5;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 5 rows affected.
# +---------------+------------------------+
# | Annual_Income | normalized_delinquency |
# +---------------+------------------------+
# |    34847.84   |        0.500000        |
# |    34847.84   |        1.000000        |
# |    30689.89   |        1.000000        |
# |   4148862.0   |        1.000000        |
# |    31370.8    |        1.000000        |
# +---------------+------------------------+

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN normalized_credit_history DECIMAL(10, 6);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET normalized_credit_history = (
#     GREATEST(0, LEAST(Credit_History_Age/120, 1))
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT Annual_Income, normalized_credit_history from risk_analysis_dataset LIMIT 5;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 5 rows affected.
# +---------------+---------------------------+
# | Annual_Income | normalized_credit_history |
# +---------------+---------------------------+
# |    34847.84   |          1.000000         |
# |    34847.84   |          1.000000         |
# |    30689.89   |          1.000000         |
# |   4148862.0   |          1.000000         |
# |    31370.8    |          1.000000         |
# +---------------+---------------------------+

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN normalized_savings DECIMAL(10, 6);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET normalized_savings = (
#     GREATEST(0, LEAST(Monthly_Balance / (Monthly_Inhand_Salary+1), 1))
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT Annual_Income, normalized_savings from risk_analysis_dataset LIMIT 5;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 5 rows affected.
# +---------------+--------------------+
# | Annual_Income | normalized_savings |
# +---------------+--------------------+
# |    34847.84   |      0.159691      |
# |    34847.84   |      0.099821      |
# |    30689.89   |      0.127396      |
# |   4148862.0   |      0.115133      |
# |    31370.8    |      0.133211      |
# +---------------+--------------------+

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN normalized_utilization DECIMAL(10, 6);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET normalized_utilization = (
#     GREATEST(0, LEAST(Credit_Utilization_Ratio, 1))
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT Annual_Income, normalized_utilization from risk_analysis_dataset LIMIT 5;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 5 rows affected.
# +---------------+------------------------+
# | Annual_Income | normalized_utilization |
# +---------------+------------------------+
# |    34847.84   |        1.000000        |
# |    34847.84   |        1.000000        |
# |    30689.89   |        1.000000        |
# |   4148862.0   |        1.000000        |
# |    31370.8    |        1.000000        |
# +---------------+------------------------+

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# RENAME COLUMN debt_to_income_ratio TO normalized_dti
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT Annual_Income, normalized_dti from risk_analysis_dataset LIMIT 5;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 5 rows affected.
# +---------------+----------------+
# | Annual_Income | normalized_dti |
# +---------------+----------------+
# |    34847.84   |     0.0174     |
# |    34847.84   |     0.0174     |
# |    30689.89   |     0.0206     |
# |   4148862.0   |     0.0002     |
# |    31370.8    |     0.0134     |
# +---------------+----------------+

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN normalized_utilization_risk DECIMAL (10, 6);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET normalized_utilization_risk = (
#
# GREATEST(0, LEAST((Credit_Utilization_Ratio+1) * (Num_Credit_Card+1), 1))
#
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT Annual_Income, normalized_utilization_risk from risk_analysis_dataset LIMIT 5;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 5 rows affected.
# +---------------+-----------------------------+
# | Annual_Income | normalized_utilization_risk |
# +---------------+-----------------------------+
# |    34847.84   |           1.000000          |
# |    34847.84   |           1.000000          |
# |    30689.89   |           1.000000          |
# |   4148862.0   |           1.000000          |
# |    31370.8    |           1.000000          |
# +---------------+-----------------------------+

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN normalized_inquiry_intensity DECIMAL(10, 6);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET normalized_inquiry_intensity = (
#
#     GREATEST(0, LEAST(Num_Credit_Inquiries / (Num_Credit_Card+1), 1))
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN normalized_investment_ratio DECIMAL(10, 6);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET normalized_investment_ratio = (
#
#     GREATEST(0, LEAST(Amount_invested_monthly / (Monthly_Inhand_Salary+1), 1))
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN normalized_loan_burden_index DECIMAL(10, 6);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET normalized_loan_burden_index = (
#
#     GREATEST(0, LEAST((Num_of_Loan+1) * (Outstanding_Debt+1), 1))
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# ALTER TABLE risk_analysis_dataset
#
# ADD COLUMN behavioral_risk_indicator INT;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# UPDATE risk_analysis_dataset
#
# SET behavioral_risk_indicator = (
#     CASE
#     WHEN Payment_of_Min_Amount = 'Yes' THEN 1
#     ELSE 0 END
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/kingametrics'
# 8744 rows affected.
# ++
# ||
# ++
# ++
